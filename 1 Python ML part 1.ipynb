# %%
import numpy
speed = [89,76,77,78,101,76,93,77,84,68,67,75,76]
x = numpy.mean(speed)
y = numpy.median(speed)
print(x) 
print(y)
# Out:
# 79.76923076923077
# 77.0

# %%
from scipy import stats
speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]
x = stats.mode(speed)
print(x)
# Out:
# ModeResult(mode=array([86]), count=array([3]))

# %%
import numpy
speed = [32,122,38,55,117,64,140]
x = numpy.mean(speed)
y = numpy.std(speed)
z = numpy.var(speed)

print(x)
print(y)
print(z)
# Out:
# 81.14285714285714
# 40.83565868708577
# 1667.5510204081634

# %%
import numpy
x = numpy.random.uniform(0.0, 8.0, 500)
print(x)
# Out:
# [1.91130185e+00 1.41678275e+00 7.59595515e+00 6.74427049e+00
#  5.08350349e+00 1.61085413e-01 7.38660036e+00 2.98392458e+00
#  6.64740073e+00 4.08938160e+00 4.81814215e+00 3.42216522e+00
#  2.50116936e+00 6.80301851e+00 2.67276333e+00 1.78239954e+00
#  5.93026558e+00 5.04295074e+00 7.50233548e-01 1.15082666e+00
#  2.34253321e-01 2.35295562e-01 9.49999657e-01 3.92108635e-01
#  2.43836765e+00 1.44709462e+00 3.55728273e+00 2.12363616e+00
#  6.59173935e-01 2.27149891e+00 4.69748442e+00 4.98964595e+00
#  1.89639981e+00 7.22051802e+00 5.81739549e+00 7.73175127e+00
#  4.98640063e-01 6.71178784e+00 7.59964090e+00 2.40788743e+00
#  7.35948284e+00 7.19966786e+00 1.68699514e+00 5.35537284e+00
#  6.01154736e+00 3.30210509e-01 2.45192955e-01 5.56591208e-01
#  2.15209504e+00 5.84694337e+00 3.53717795e+00 7.28863623e+00
#  3.51426034e+00 4.26263926e+00 1.82773547e+00 5.51035973e+00
#  7.00591484e+00 3.74599328e+00 3.73732656e+00 2.43275368e+00
# ...

# %%
#Matplotlib histogram
import numpy
import matplotlib.pyplot as plt
x = numpy.random.uniform(0.0, 8.0, 250)
plt.hist(x, 5)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.uniform(0.0, 9.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = numpy.random.normal(5.0, 1.0, 100000)

plt.hist(x, 100)
plt.show()

# %%
import pandas as pd
import os
covid = pd.read_csv("E:/CCMP Lab/Anand Paul/Anaconda3/statistic_id1102777_covid-19-daily-new-cases-south-korea-2020.csv")
covid.head()
covid
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-1c41ed7e0bc0> in <module>
#       1 import pandas as pd
#       2 import os
# ----> 3 covid = pd.read_csv("E:/CCMP Lab/Anand Paul/Anaconda3/statistic_id1102777_covid-19-daily-new-cases-south-korea-2020.csv")
#       4 covid.head()
#       5 covid
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 100
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (20 * np.random.rand(N))**2  # 0 tp 15 radius
plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show() 
print(r)
# Out:
# -0.758591524376155

# %%
from scipy import stats

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

speed = myfunc(20)

print(speed)
# Out:
# 68.08020603384843

# %%
import matplotlib.pyplot as plt
from scipy import stats

x = [89,43,36,36,95,10,66,34,38,20,26,29,48,64,6,5,36,66,72,40]
y = [21,46,3,35,67,95,53,72,58,10,26,34,90,33,38,20,56,2,47,15]

slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
  return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
import pandas as pd
df = pd.read_csv('time_series_covid19_confirmed_global.csv')

df
# Out:
#                Province/State  Country/Region      Lat     Long  1/22/20  \
# 0                         NaN     Afghanistan  33.0000  65.0000        0
# 1                         NaN         Albania  41.1533  20.1683        0
# 2                         NaN         Algeria  28.0339   1.6596        0
# 3                         NaN         Andorra  42.5063   1.5218        0
# 4                         NaN          Angola -11.2027  17.8739        0
# ..                        ...             ...      ...      ...      ...
# 248                       NaN           Burma  21.9162  95.9560        0
# 249                  Anguilla  United Kingdom  18.2206 -63.0686        0
# 250    British Virgin Islands  United Kingdom  18.4207 -64.6400        0
# 251  Turks and Caicos Islands  United Kingdom  21.6940 -71.7979        0
# 252                       NaN      MS Zaandam   0.0000   0.0000        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/19/20  3/20/20  \
# ...

# %%
import pandas as pd
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
data = pd.read_csv('daily_weather.csv')
data.columns
data
# Out:
#       number  air_pressure_9am  air_temp_9am  avg_wind_direction_9am  \
# 0          0        918.060000     74.822000              271.100000
# 1          1        917.347688     71.403843              101.935179
# 2          2        923.040000     60.638000               51.000000
# 3          3        920.502751     70.138895              198.832133
# 4          4        921.160000     44.294000              277.800000
# ...      ...               ...           ...                     ...
# 1090    1090        918.900000     63.104000              192.900000
# 1091    1091        918.710000     49.568000              241.600000
# 1092    1092        916.600000     71.096000              189.300000
# 1093    1093        912.600000     58.406000              172.700000
# 1094    1094        921.530000     77.702000               97.100000
#
#       avg_wind_speed_9am  max_wind_direction_9am  max_wind_speed_9am  \
# ...

# %%
import numpy
from sklearn.metrics import r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

speed = mymodel(17)
print(speed)
# Out:
# 88.87331269697987

# %%
#pandas
import pandas as pd
data = {
    'apples': [3, 2, 0, 1], 
    'oranges': [0, 3, 7, 2]
}
purchases = pd.DataFrame(data)
purchases = pd.DataFrame(data, index=['June', 'Robert', 'Lily', 'David'])
purchases
# Out:
#         apples  oranges
# June         3        0
# Robert       2        3
# Lily         0        7
# David        1        2

# %%
purchases.loc['June']
# Out:
# apples     3
# oranges    0
# Name: June, dtype: int64

# %%
import pandas as pd
df = pd.read_csv('time_series_covid19_confirmed_global.csv')

df
# Out:
#                Province/State  Country/Region      Lat     Long  1/22/20  \
# 0                         NaN     Afghanistan  33.0000  65.0000        0
# 1                         NaN         Albania  41.1533  20.1683        0
# 2                         NaN         Algeria  28.0339   1.6596        0
# 3                         NaN         Andorra  42.5063   1.5218        0
# 4                         NaN          Angola -11.2027  17.8739        0
# ..                        ...             ...      ...      ...      ...
# 248                       NaN           Burma  21.9162  95.9560        0
# 249                  Anguilla  United Kingdom  18.2206 -63.0686        0
# 250    British Virgin Islands  United Kingdom  18.4207 -64.6400        0
# 251  Turks and Caicos Islands  United Kingdom  21.6940 -71.7979        0
# 252                       NaN      MS Zaandam   0.0000   0.0000        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/19/20  3/20/20  \
# ...

# %%
covid = pd.read_csv('time_series_covid19_confirmed_global.csv')
covid.head()
covid
# Out:
#                Province/State  Country/Region      Lat     Long  1/22/20  \
# 0                         NaN     Afghanistan  33.0000  65.0000        0
# 1                         NaN         Albania  41.1533  20.1683        0
# 2                         NaN         Algeria  28.0339   1.6596        0
# 3                         NaN         Andorra  42.5063   1.5218        0
# 4                         NaN          Angola -11.2027  17.8739        0
# ..                        ...             ...      ...      ...      ...
# 248                       NaN           Burma  21.9162  95.9560        0
# 249                  Anguilla  United Kingdom  18.2206 -63.0686        0
# 250    British Virgin Islands  United Kingdom  18.4207 -64.6400        0
# 251  Turks and Caicos Islands  United Kingdom  21.6940 -71.7979        0
# 252                       NaN      MS Zaandam   0.0000   0.0000        0
#
#      1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  3/19/20  3/20/20  \
# ...

# %%
covid.shape
# Out:
# (253, 71)

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(20,5))
df
# Out:
#            0         1         2         3         4
# 0  -0.931298  0.921930 -0.321108 -0.509440 -0.097915
# 1  -1.362979 -0.338756  0.262098  0.499831  0.035262
# 2  -0.881366 -0.887072 -0.379061 -0.736915  0.205272
# 3  -0.837678  1.005289 -0.194470  0.971525 -1.346407
# 4  -0.100685 -0.312513 -0.142977  0.342950 -0.576934
# 5   0.515149  1.024211 -0.087130 -0.015690 -1.623589
# 6   1.002757  1.154756 -0.946634 -0.304880  0.181013
# 7   0.698002  1.726123  1.290897 -0.151785 -0.328703
# 8   0.522769  0.150323 -1.502985  0.188585  0.210017
# 9   0.092464 -0.365368 -0.341825  0.218786  0.619006
# 10 -0.612104 -1.255079 -1.597515  2.137534  0.009991
# 11  0.183265 -0.039209 -0.657121  0.133875 -0.826658
# 12  1.380763  0.247864 -1.943570  0.007727  0.077127
# 13  1.048648  1.518448  0.076628 -0.262545  0.045975
# 14 -0.578701  0.405781 -0.318334  0.251484 -1.255751
# 15  1.902377  1.503954  0.234193  1.344223  0.353010
# 16  0.866094 -0.432273 -0.158269  1.926777  2.321893
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
N = 100
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.pi * (20 * np.random.rand(N))**2  # 0 tp 20 radius
plt.scatter(x,y, s=area, c=colors, alpha=0.5)
plt.show()
